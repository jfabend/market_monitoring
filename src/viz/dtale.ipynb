# %%
import pandas as pd
import dtale
from db.get_dbtable_data import get_dbtable_data

db_table_name = "prepped_20201115"
data = get_dbtable_data(db_table_name)

dtale.show(data)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://MININT-RR2EIHI:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
