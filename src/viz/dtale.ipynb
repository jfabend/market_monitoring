# %%
import pandas as pd
import dtale
from db.get_dbtable_data import get_dbtable_data

db_table_name = "prepped_20210519"
data = get_dbtable_data(db_table_name)

dtale.show(data)
# dtale.show(data)._main_url
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://MININT-RR2EIHI:40000/dtale/iframe/2"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
