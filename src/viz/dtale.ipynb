# %%
import pandas as pd
import dtale
from db.get_dbtable_data import get_dbtable_data

db_table_name = "prepped_20210521"
data = get_dbtable_data(db_table_name)

dtale.show(data)
# dtale.show(data)._main_url
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1585         try:
# -> 1586             cur.execute(*args, **kwargs)
#    1587             return cur
#
# UndefinedTable: relation "prepped_20210519" does not exist
# LINE 1: SELECT * FROM prepped_20210519;
#                       ^
#
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-1-214d2914805e> in <module>
#       4
#       5 db_table_name = "prepped_20210519"
# ----> 6 data = get_dbtable_data(db_table_name)
#       7
#       8 dtale.show(data)
#
# C:\Data\Trading\market_monitoring\src\db\get_dbtable_data.py in get_dbtable_data(tablename)
#      21     query = f"SELECT * FROM {tablename};"
#      22
# ...
